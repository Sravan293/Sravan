# %%
# Pandas, Matplotlib, Seaborn and other tutorials for project

# Data used: IRIS DATA

# Data source: https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data

"""

Project goals:

1. Understand Pandas, Matplotlib, Seaborn and other libraries for loading data, cleaning data,
descriptive analysis of data, and visualization of data

2. Form research questions about the data and try to answer them using Python. Example of research question are:

Q1: Are the mean, IQR, minimum, and maximum values of the three classes
in the IRIS data similar or different across the three classes?

Q2: Are the outliers in the three classes similar or different in number and quantity?

Q3: Are the four variables highly correlated with each other? If yes which ones?

"""

# %%
# Import data from csv file, rename column, create dictionary from dataframe using for loop


import os
import pandas as pd
import time

# Load data
df = pd.read_csv('/content/iris.csv', header='infer')
# rename the class column to classes
df.rename(columns = {'class' : 'classes'}, inplace = True)


# make classes column values unique by appending the row number.
# This is done to make them dictionary keys later.
for i in range(len(df)):
  df.classes[i] = str(i) + df.classes[i]

display(df.shape)
display(df.head())

# Creating a dictionary from the df dataframe using vanilla for loop
# the classes column will be the key and all other columns will be values

# Also calculating the time to run the below code
start_time = time.time()

df_zip = zip(df.classes, df.sepal_length, df.sepal_width,df.petal_length, df.petal_width)

# creating dictionary using vanilla for loop.
# This can be done using dictionary comprehension also which is similar to list comprehension.
dic_using_forloop = {}
for i, a, b, c, d in df_zip:
  dic_using_forloop.update({i:[a, b, c, d]})

# printing the time to run
print("Time to run =  %s seconds " % (time.time() - start_time))

display(dic_using_forloop)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# (150, 5)
#    sepal_length  sepal_width  petal_length  petal_width       classes
# 0           5.1          3.5           1.4          0.2  0Iris-setosa
# 1           4.9          3.0           1.4          0.2  1Iris-setosa
# 2           4.7          3.2           1.3          0.2  2Iris-setosa
# 3           4.6          3.1           1.5          0.2  3Iris-setosa
# 4           5.0          3.6           1.4          0.2  4Iris-setosa
# Time to run =  0.0014998912811279297 seconds
# {'0Iris-setosa': [5.1, 3.5, 1.4, 0.2],
#  '100Iris-virginica': [6.3, 3.3, 6.0, 2.5],
#  '101Iris-virginica': [5.8, 2.7, 5.1, 1.9],
#  '102Iris-virginica': [7.1, 3.0, 5.9, 2.1],
# ...

# %%
# Import data directly from URL

# Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


# LOAD DATA
# if data is stored in csv file then use read_csv to load the data
# iris_data = pd.read_csv(‘iris.csv’)

# Read data from excel file
#pd.read_excel('del_26Mar.xls', index_col=False)

# Save dataframe in local file
#df.to_excel('df.xls', sheet_name='sheet1', float_format = "%.2f", index=False)
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'

# if data is obtained from website link then use the genfromtxt function
raw_data = np.genfromtxt(url, delimiter=',', dtype=None,  names = ["sepal_length", "sepal_width", "petal_length", "petal_width", "classes"])
display(raw_data.dtype)
display(raw_data[:10])
print()

# Converting numpy array to pandas dataframe
df = pd.DataFrame({'sepal_length': raw_data['sepal_length'], 'sepal_width': raw_data['sepal_width'], 'petal_length': raw_data['petal_length'], 'petal_width': raw_data['petal_width'],'classes': raw_data['classes']})
df['classes'] = df['classes'].str.decode('utf-8') # to handle byte object and remove the b string in classes
pd.set_option('display.max_rows', 500) # to show 500 rows
display(df.shape)
display(df.head(10))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:22: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
# dtype([('sepal_length', '<f8'), ('sepal_width', '<f8'), ('petal_length', '<f8'), ('petal_width', '<f8'), ('classes', 'S15')])
# array([(5.1, 3.5, 1.4, 0.2, b'Iris-setosa'),
#        (4.9, 3. , 1.4, 0.2, b'Iris-setosa'),
#        (4.7, 3.2, 1.3, 0.2, b'Iris-setosa'),
#        (4.6, 3.1, 1.5, 0.2, b'Iris-setosa'),
#        (5. , 3.6, 1.4, 0.2, b'Iris-setosa'),
#        (5.4, 3.9, 1.7, 0.4, b'Iris-setosa'),
#        (4.6, 3.4, 1.4, 0.3, b'Iris-setosa'),
#        (5. , 3.4, 1.5, 0.2, b'Iris-setosa'),
#        (4.4, 2.9, 1.4, 0.2, b'Iris-setosa'),
#        (4.9, 3.1, 1.5, 0.1, b'Iris-setosa')],
#       dtype=[('sepal_length', '<f8'), ('sepal_width', '<f8'), ('petal_length', '<f8'), ('petal_width', '<f8'), ('classes', 'S15')])
# (150, 5)
# ...

# %%
# Descriptive Data Analysis

df.info()

'''
1 All columns are not having any Null Entries
2 Four columns are numerical type
3 Only Single column categorical type
'''
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   classes       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
# '\n1 All columns are not having any Null Entries\n2 Four columns are numerical type\n3 Only Single column categorical type\n'

# %%
# Describe data

df.describe()

# Data Insights:
# Mean values
# Standard Deviation,
# Minimum Values
# Maximum Values
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
# Checking For Duplicate Entries

df[df.duplicated()]

# There are 3 duplicates, therefore we must check whether each class is balanced or not balanced
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         classes
# 34            4.9          3.1           1.5          0.1     Iris-setosa
# 37            4.9          3.1           1.5          0.1     Iris-setosa
# 142           5.8          2.7           5.1          1.9  Iris-virginica

# %%
# Remove duplicate rows

df.drop_duplicates(subset=None, keep='first', inplace=False, ignore_index=False)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width          classes
# 0             5.1          3.5           1.4          0.2      Iris-setosa
# 1             4.9          3.0           1.4          0.2      Iris-setosa
# 2             4.7          3.2           1.3          0.2      Iris-setosa
# 3             4.6          3.1           1.5          0.2      Iris-setosa
# 4             5.0          3.6           1.4          0.2      Iris-setosa
# 5             5.4          3.9           1.7          0.4      Iris-setosa
# 6             4.6          3.4           1.4          0.3      Iris-setosa
# 7             5.0          3.4           1.5          0.2      Iris-setosa
# 8             4.4          2.9           1.4          0.2      Iris-setosa
# 9             4.9          3.1           1.5          0.1      Iris-setosa
# 10            5.4          3.7           1.5          0.2      Iris-setosa
# ...

# %%
# Checking whether class is balanced

df['classes'].value_counts()

# yes the classes are balanced
# Out:
# Iris-virginica     50
# Iris-versicolor    50
# Iris-setosa        50
# Name: classes, dtype: int64

# %%
# visualization

plt.title('Species Count')
sns.countplot(df['classes'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# One piece of information missing in the plots above is what species each plant is
# We'll use seaborn's FacetGrid to color the scatterplot by species

sns.FacetGrid(df, hue="class", size=5) \
   .map(plt.scatter, "sepal_length", "sepal_width") \
   .add_legend()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
# We can look at an individual feature in Seaborn through a boxplot
sns.boxplot(x="class", y="petal_length", data=df)

# %%
# One way we can extend this plot is adding a layer of individual points on top of
# it through Seaborn's striplot
#
# We'll use jitter=True so that all the points don't fall in single vertical lines
# above the species
#
# Saving the resulting axes as ax each time causes the resulting plot to be shown
# on top of the previous axes
ax = sns.boxplot(x="class", y="petal_length", data=df)
ax = sns.stripplot(x="class", y="petal_length", data=df, jitter=True, edgecolor="gray")

# %%
# A violin plot combines the benefits of the previous two plots and simplifies them
# Denser regions of the data are fatter, and sparser thiner in a violin plot
sns.violinplot(x="class", y="petal_length", data=df, size=6)

# %%
# Uni-variate Analysis
# Comparison between various species based on sepal length and width

plt.figure(figsize=(17,9))
plt.title('Comparison between various species based on sapel length and width')
sns.scatterplot(df['sepal_length'],df['sepal_width'],hue =df['class'], s=150)

# Data Insights:
# Iris Setosa species has smaller sepal length but higher width.
# Versicolor lies in almost middle for length as well as width
# Virginica has larger sepal lengths and smaller sepal widths
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# Comparison between various species based on petal length and width

plt.figure(figsize=(16,9))
plt.title('Comparison between various species based on petal lenght and width')
sns.scatterplot(df['petal_length'], df['petal_width'], hue = df['class'], s= 150)

# Data Insights
# Setosa species have the smallest petal length as well as petal width
# Versicolor species have average petal length and petal width
# Virginica species have the highest petal length as well as petal width
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# Bi-variate Analysis

sns.pairplot(df,hue='class',height=4)

# Data Insights:
# High co relation between petal length and width columns.
# Setosa has both low petal length and width
# Versicolor has both average petal length and width
# Virginica has both high petal length and width.
# Sepal width for setosa is high and length is low.
# Versicolor have average values for for sepal dimensions.
# Virginica has small width but large sepal length

# %%
# Checking Correlation

plt.figure(figsize=(10,11))
sns.heatmap(df.corr(),annot=True)
plt.plot()

# Data Insights:
# Sepal Length and Sepal Width features are slightly correlated with each other
# Out:
# []

# %%
# Checking Mean & Median Values for each species
df.groupby('class').agg(['mean', 'median'])
# Out:
#                 sepal_length        sepal_width  ... petal_length petal_width
#                         mean median        mean  ...       median        mean median
# class                                            ...
# Iris-setosa            5.006    5.0       3.418  ...         1.50       0.244    0.2
# Iris-versicolor        5.936    5.9       2.770  ...         4.35       1.326    1.3
# Iris-virginica         6.588    6.5       2.974  ...         5.55       2.026    2.0
#
# [3 rows x 8 columns]

# %%
# visualizing the distribution , mean and median using box plots & violin plots
# Box plots to know about distribution
# boxplot to see how the categorical feature “Species” is distributed with all other four input variables

fig, axes = plt.subplots(2, 2, figsize=(16,9))
sns.boxplot( y='petal_width', x= 'class', data=df, orient='v' , ax=axes[0, 0])
sns.boxplot( y='petal_length', x= 'class', data=df, orient='v' , ax=axes[0, 1])
sns.boxplot( y='sepal_length', x= 'class', data=df, orient='v' , ax=axes[1, 0])
sns.boxplot( y='sepal_width', x= 'class', data=df, orient='v' , ax=axes[1, 1])
plt.show()

"""
Data Insights:
Setosa is having smaller feature and less distributed
Versicolor is distributed in a average manner and average features
Virginica is highly distributed with large no .of values and features
Clearly the mean/ median values are being shown by each plots for various features(sepal length & width, petal length & width)
"""
# Out:
# '\nData Insights:\nSetosa is having smaller feature and less distributed\nVersicolor is distributed in a average manner and average features\nVirginica is highly distributed with large no .of values and features\nClearly the mean/ median values are being shown by each plots for various features(sepal length & width, petal length & width)\n'

# %%
"""
Violin Plot for checking distribution
The violin plot shows density of the length and width in the species. The thinner part denotes that there is less density whereas the fatter part conveys higher density
"""

fig, axes = plt.subplots(2, 2, figsize=(16,10))
sns.violinplot( y='petal_width', x= 'class', data=df, orient='v' , ax=axes[0, 0],inner='quartile')
sns.violinplot( y='petal_length', x= 'class', data=df, orient='v' , ax=axes[0, 1],inner='quartile')
sns.violinplot( y='sepal_length', x= 'class', data=df, orient='v' , ax=axes[1, 0],inner='quartile')
sns.violinplot( y='sepal_width', x= 'class', data=df, orient='v' , ax=axes[1, 1],inner='quartile')
plt.show()

"""
Data Insights:
Setosa is having less distribution and density in case of petal length & width
Versicolor is distributed in a average manner and average features in case of petal length & width
Virginica is highly distributed with large no .of values and features in case of sepal length & width
High density values are depicting the mean/median values, for example: Iris Setosa has highest density at 5.0 cm ( sepal length feature)
"""
# Out:
# '\nData Insights:\nSetosa is having less distribution and density in case of petal length & width\nVersicolor is distributed in a average manner and average features in case of petal length & width\nVirginica is highly distributed with large no .of values and features in case of sepal length & width\nHigh density values are depicting the mean/median values, for example: Iris Setosa has highest density at 5.0 cm ( sepal length feature) \n'

# %%
"""
Plotting the Histogram & Probability Density Function (PDF)
plotting the probability density function(PDF) with each feature as a variable on X-axis and it’s histogram and corresponding kernel density plot on Y-axis.
"""

sns.FacetGrid(df, hue="class", height=5) \
.map(sns.distplot, "sepal_length") \
.add_legend()
sns.FacetGrid(df, hue="class", height=5) \
.map(sns.distplot, "sepal_width") \
.add_legend()
sns.FacetGrid(df, hue="class", height=5) \
.map(sns.distplot, "petal_length") \
.add_legend()
sns.FacetGrid(df, hue="class", height=5) \
.map(sns.distplot, "petal_width") \
.add_legend()
plt.show()


"""
Data Insights:
Plot 1 shows that there is a significant amount of overlap between the species on sepal length, so it is not an effective Classification feature
Plot 2 shows that there is even higher overlap between the species on sepal width, so it is not an effective Classification feature
Plot 3 shows that petal length is a good Classification feature as it clearly separates the species . The overlap is extremely less (between Versicolor and
Virginica) , Setosa is well separated from the rest two
Just like Plot 3, Plot 4 also shows that petal width is a good Classification feature . The overlap is significantly less (between Versicolor and Virginica) ,
Setosa is well separated from the rest two
"""
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
# Scatterplot
sns.scatterplot(x=df['sepal_length'], y=df['sepal_width']);

# %%
# Joinplot
sns.jointplot(x=df['sepal_length'], y=df['sepal_width']);

# %%
# Groupby

sorted_df = df.groupby(['class'])['sepal_width'].median().sort_values()
sns.boxplot(x=df['class'], y=df['sepal_width'], order=list(sorted_df.index))

# %%
# Facetgrid function

cond_plot = sns.FacetGrid(data=df, col='class', hue='petal_length', col_wrap=3)
cond_plot.map(sns.scatterplot, 'sepal_length', 'sepal_width');

# %%
# multiple swarmplot using seaborn

order = ['Iris-setosa', 'Iris-versicolor', 'Iris-virginica']
# Initialise the subplot function using number of rows and columns
figure, axis = plt.subplots(2, 2)
sns.swarmplot(x="class", y="sepal_length", data=df, order=order, ax = axis[0, 0])
sns.swarmplot(x="class", y="sepal_width", data=df, order=order,  ax = axis[0, 1])
sns.swarmplot(x="class", y="petal_length", data=df, order=order, ax = axis[1, 0])
sns.swarmplot(x="class", y="petal_width", data=df, order=order,  ax = axis[1, 1])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 18.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 6.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 8.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 16.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
# multiple plots using matplotlib

fig, ax = plt.subplots(2,2)
ax[0, 0].plot(df.sepal_width, df.sepal_length, )
ax[0, 0].set_title('Axis [0, 0]')

ax[0, 1].plot(df.petal_width, df.petal_length, )
ax[0, 1].set_title('Axis [0, 1]')

ax[1, 0].plot(df.sepal_width, df.petal_length, )
ax[1, 0].set_title('Axis [1, 0]')

ax[1, 1].plot(df.petal_width, df.sepal_length, )
ax[1, 1].set_title('Axis [1, 1]')
# Out:
# Text(0.5, 1.0, 'Axis [1, 1]')

# %%
# index of dataframe

print(df.head(), '\n')

print(df.index, '\n')

print(df.index[5], '\n')
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
#
# RangeIndex(start=0, stop=150, step=1)
#
# 5

# %%
# accessing dataframe rows and columns using iloc

df.iloc[:1, :5]
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa

# %%
# accessing df using loc
df.loc[1]
# Out:
# sepal_length            4.9
# sepal_width               3
# petal_length            1.4
# petal_width             0.2
# class           Iris-setosa
# Name: 1, dtype: object

# %%
# accessing df using loc
df.loc[[1]]
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 1           4.9          3.0           1.4          0.2  Iris-setosa

# %%
# Accessing df using loc

res = df.loc[df['class'] == 'Iris-virginica', ['petal_length', 'petal_width']]
print(res.head())
# Out:
#      petal_length  petal_width
# 100           6.0          2.5
# 101           5.1          1.9
# 102           5.9          2.1
# 103           5.6          1.8
# 104           5.8          2.2

# %%
# There are many ways to deal with missing data

df.petal_length = df.petal_length.fillna('')

# This replaces the NaN entries in the ‘petal_length’ column with the empty string.

# %%
# There are many ways to deal with missing data

# df.petal_length = df.petal_length.fillna(df.petal_length.mean())

df.petal_length = df.petal_length.fillna(df.petal_length.median())

# This replaces the NaN entries in the ‘petal_length’ column with the mean of that column.

# %%
# Dropping all rows with ANY NA values

df.dropna(axis=0)

# %%
# dropping all rows that have ALL NA values:

df.dropna(how='all', axis = 0)

# %%
# Drop all columns that have all NA values

df.dropna(axis=1, how='all')

# %%
# Drop all columns with any NA values:

df.dropna(axis=1, how='any')

# %%
# check for missing value in a column
print(df['petal_width'].isnull())
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 145    False
# 146    False
# 147    False
# 148    False
# 149    False
# Name: petal_width, Length: 150, dtype: bool

# %%
# The default pandas missing value is NA
# Making a list of non-standard missing values when loading the file so that they can be detected

# missing_values = ["n/a", "na", "--"]
# df = pd.read_csv("yourdatafile.csv", na_values = missing_values)

# %%
# Change class data type to category
print(df.info(), '\n')

df['class'] = df['class'].astype('category')
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   class         150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
# None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   class         150 non-null    category
# dtypes: category(1), float64(4)
# memory usage: 5.1 KB
# None

# %%
# check for null values
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# class           0
# dtype: int64

# %%
# Renaming DataFrame classes

df['class'].cat.rename_categories(new_categories={'Iris-setosa':'C1', 'Iris-versicolor':'C2', 'Iris-virginica':'C3'}, inplace=True)
print(df['class'].value_counts(), '\n')

print(df.head())
# Out:
# C3    50
# C2    50
# C1    50
# Name: class, dtype: int64
#
#    sepal_length  sepal_width  petal_length  petal_width class
# 0           5.1          3.5           1.4          0.2    C1
# 1           4.9          3.0           1.4          0.2    C1
# 2           4.7          3.2           1.3          0.2    C1
# 3           4.6          3.1           1.5          0.2    C1
# 4           5.0          3.6           1.4          0.2    C1

# %%
# groupby
res = df.groupby(['class']).size().reset_index(name='counts')
print(res)
# Out:
#   class  counts
# 0    C1      50
# 1    C2      50
# 2    C3      50

# %%
# groupby
res = (df.groupby(['class']).agg({'petal_length': ['mean', 'count'], 'petal_width': ['median', 'min', 'count']}))
res
# Out:
#       petal_length       petal_width
#               mean count      median  min count
# class
# C1           1.464    50         0.2  0.1    50
# C2           4.260    50         1.3  1.0    50
# C3           5.552    50         2.0  1.4    50

# %%
# groupby
df.groupby(['class']).agg(['mean', 'count'])
# Out:
#       sepal_length       sepal_width       petal_length       petal_width
#               mean count        mean count         mean count        mean count
# class
# C1           5.006    50       3.418    50        1.464    50       0.244    50
# C2           5.936    50       2.770    50        4.260    50       1.326    50
# C3           6.588    50       2.974    50        5.552    50       2.026    50
